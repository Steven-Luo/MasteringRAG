# %% [markdown]
# 生成的答案打分用

# %%
# %env LLM_BASE_URL=https://dashscope.aliyuncs.com/compatible-mode/v1
# %env LLM_API_KEY=替换为自己的key
# Out:
# env: LLM_BASE_URL=https://dashscope.aliyuncs.com/compatible-mode/v1
# env: LLM_API_KEY=替换为自己的key

# %%
# %%capture --no-stderr
# !pip install -U langchain langchain_community langchain_openai pypdf sentence_transformers chromadb shutil

# %%
import langchain, langchain_community, pypdf, sentence_transformers, chromadb, langchain_core

for module in (langchain, langchain_core, langchain_community, pypdf, sentence_transformers, chromadb):
    print(f"{module.__name__:<30}{module.__version__}")
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2024-08-17 18:25:13.769246: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-17 18:25:13.801270: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 18:25:14.408933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# langchain                     0.2.10
# langchain_core                0.2.28
# langchain_community           0.2.9
# pypdf                         4.3.1
# sentence_transformers         3.0.1
# chromadb                      0.5.4

# %%
import os
import pandas as pd

# %%
expr_version = 'retrieval_v2_multi_query'

preprocess_output_dir = os.path.join(os.path.pardir, 'outputs', 'v1_20240713')
expr_dir = os.path.join(os.path.pardir, 'experiments', expr_version)

# %% [markdown]
# # 读取文档

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(os.path.join(os.path.pardir, 'data', '2024全球经济金融展望报告.pdf'))
documents = loader.load()

qa_df = pd.read_excel(os.path.join(preprocess_output_dir, 'question_answer.xlsx'))

# %% [markdown]
# # 文档切分

# %%
from uuid import uuid4
import os
import pickle

from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents, filepath, chunk_size=400, chunk_overlap=40, seperators=['\n\n\n', '\n\n'], force_split=False):
    if os.path.exists(filepath) and not force_split:
        print('found cache, restoring...')
        return pickle.load(open(filepath, 'rb'))

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=seperators
    )
    split_docs = splitter.split_documents(documents)
    for chunk in split_docs:
        chunk.metadata['uuid'] = str(uuid4())

    pickle.dump(split_docs, open(filepath, 'wb'))

    return split_docs

# %%
splitted_docs = split_docs(documents, os.path.join(preprocess_output_dir, 'split_docs.pkl'), chunk_size=500, chunk_overlap=50)
# Out:
# found cache, restoring...

# %% [markdown]
# # 检索

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import Chroma
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'device: {device}')

def get_embeddings(model_path):
    embeddings = HuggingFaceBgeEmbeddings(
        model_name=model_path,
        model_kwargs={'device': device},
        encode_kwargs={'normalize_embeddings': True},
        # show_progress=True
        query_instruction='为这个句子生成表示以用于检索相关文章：'
    )
    return embeddings
# Out:
# device: cuda

# %%
import shutil
from langchain_community.vectorstores import Chroma

# 此处可以替换为本地路径
model_path = 'BAAI/bge-large-zh-v1.5'

persist_directory = os.path.join(expr_dir, 'chroma')
shutil.rmtree(persist_directory, ignore_errors=True)

embeddings = get_embeddings(model_path)
vector_db = Chroma.from_documents(
    splitted_docs,
    embedding=embeddings,
    persist_directory=persist_directory
)

# %%
test_df = qa_df[(qa_df['dataset'] == 'test') & (qa_df['qa_type'] == 'detailed')]

# %% [markdown]
# ## 不使用Multi-Query

# %%
def get_emb_retriever(k):
    return vector_db.as_retriever(search_kwargs={'k': k})

# %%
from tqdm.auto import tqdm

def get_hit_stat_df(get_retriever_fn, top_k_arr=list(range(1, 9))):
    hit_stat_data = []
    pbar = tqdm(total=len(top_k_arr) * len(test_df))
    for k in top_k_arr:
        pbar.set_description(f'k={k}')
        retriever = get_retriever_fn(k)
        for idx, row in test_df.iterrows():
            question = row['question']
            true_uuid = row['uuid']
            # 在langchain_core/retrievers.py中，get_relevant_documents方法已经被标注为禁用，将在0.3.0版本移除
            # 推荐使用invoke方法
            chunks = retriever.invoke(question)[:k]
            retrieved_uuids = [doc.metadata['uuid'] for doc in chunks]

            hit_stat_data.append({
                'question': question,
                'top_k': k,
                'hit': int(true_uuid in retrieved_uuids),
                'retrieved_chunks': len(chunks)
            })
            pbar.update(1)
    hit_stat_df = pd.DataFrame(hit_stat_data)
    return hit_stat_df

# %%
orig_query_hit_stat_df = get_hit_stat_df(get_emb_retriever)
orig_query_hit_stat_df['multi_query'] = 'w/o'
# Out:
#   0%|          | 0/744 [00:00<?, ?it/s]

# %%
orig_query_hit_stat_df.groupby('top_k')['hit'].mean().reset_index().rename(columns={'hit': 'hit_rate'})
# Out:
#    top_k  hit_rate
# 0      1  0.462366
# 1      2  0.591398
# 2      3  0.688172
# 3      4  0.774194
# 4      5  0.806452
# 5      6  0.817204
# 6      7  0.838710
# 7      8  0.849462

# %% [markdown]
# ## 使用Multi Query

# %%
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(base_url='http://localhost:11434', model='qwen2:7b-instruct')

# %% [markdown]
# ### 最简用法

# %%
from langchain.retrievers import MultiQueryRetriever
import logging

def get_multi_query_retriever(k):
    retriever = MultiQueryRetriever.from_llm(
        retriever=vector_db.as_retriever(search_kwargs={'k': k}),
        llm=llm
    )
    return retriever

logging.basicConfig()
logging.getLogger("langchain.retrievers.multi_query").setLevel(logging.INFO)

# %%
get_multi_query_retriever(k=2).invoke('报告的发布机构是什么？')
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个组织或实体发布了这份报告？', '2. 谁是该报告的出版者或赞助商？', '3. 请问这份报告是由哪个官方或非官方机构发布的？']
# [Document(metadata={'page': 33, 'source': 'data/2024全球经济金融展望报告.pdf', 'uuid': '3e312dfa-dd43-4ab9-961f-a2e442c89cdd'}, page_content='全球经济金融展望报告\n中国银行研究院 32 2024年\n图19：美国联邦基金目标利率与全球MSCI指数\n资料来源：Wind，中国银行研究院\n表3：全球主要股指概览\n注：涨跌幅区间为2023年1月1日至2023年11月15日，收盘价和市盈\n率为2023年11月15日。\n资料来源：Wind，中国银行研究院'),
#  Document(metadata={'page': 22, 'source': 'data/2024全球经济金融展望报告.pdf', 'uuid': '8cf24c61-8169-41e5-8e05-870bf85a4bc8'}, page_content='全球经济金融展望报告\n中国银行研究院 21 2024年\n专栏2：全球发展中国家合作进展\n2023年，上海合作组织（上合组织）成员国元首理事会第二十三次会议、中国－中亚峰会、金砖\n国家第十五次领导人会晤（金砖会议）和第三届“一带一路”国际合作高峰论坛（高峰论坛）先后召\n开，全球发展中国家在国际政经舞台表现突出。\n发展中国家在货币合作和组织机制建设方面取得实质性进展。多国扩大本币使用。3月，中国与\n巴西签署在巴西建立人民币清算安排的合作备忘录，10月
n经济体增长态势和货币政策走势将进一步分化。欧美\n央行大概率结束本轮紧缩货币周期，美元指数将逐步\n走弱，流向新兴经济体的跨境资本将增加。国际原油\n市场短缺格局或延续，新能源发展成为重点。\n●海湾六国经济发展与投资前景、高利率和高债务对\n美国房地产市场脆弱性的影响等热点问题值得关注。中国银行研究院\n全球经济金融研究课题组\n组长：陈卫东\n副组长：钟红\n廖淑萍\n成员：边卫红\n熊启跃\n王有鑫\n曹鸿宇\n李颖婷\n王宁远\n初晓\n章凯莉\n黄小军（纽约）\n陆晓明（纽约）\n黄承煜（纽约）\n宋达志（伦敦）\n李振龙（伦敦）\n张传捷（伦敦）\n刘冰彦（法兰克福）\n温颍坤（法兰克福）\n张明捷（法兰克福）\n王哲（东京）\n李彧（香港）\n黎永康（香港）\n联系人：王有鑫\n电话：010-66594127\n邮件：wangyouxin_hq@bank-of-china.com主要经济体GDP增速变化趋势（%）\n资料来源：IMF，中国银行研究院'),
#  Document(metadata={'page': 51, 'source': 'data/2024全球经济金融展望报告.pdf', 'uuid': 'ebf0d999-59f6-4fd3-941e-05a7a60c255a'}, page_content='免责声明\n本研究报告由中国银行研究院撰写，研究报告中所引用信息均来自公开资料。\n本研究报告中包含的观点或估计仅代表作者迄今为止的判断，它们不一定反映中国银行的观点。中国\n银行研究院可以不经通知加以改变，且没有对此报告更新、修正或修改的责任。\n本研究报告内容及观点仅供参考，不构成任何投资建议。对于本报告所提供信息所导致的任何直接的\n或者间接的投资盈亏后果不承担任何责任。\n本研究报告版权仅为中国银行研究院所有，未经书面许可，任何机构和个人不得以任何形式翻版、复\n制和发布。如引用发布，需注明出处为中国银行研究院，且不得对本报告进行有悖原意的引用、删节和修\n改。中国银行研究院保留对任何侵权行为和有悖报告原意的引用行为进行追究的权利。')]

# %%
len(get_multi_query_retriever(k=2).invoke('报告的发布机构是什么？'))
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个组织或实体发布了这份报告？', '2. 谁是该报告的出版方或者来源？', '3. 这份报告是由哪个官方或非官方机构编制并发布的？']
# 3

# %% [markdown]
# 由于是对每个相似问做召回，因此最终的结果是这些召回的并集，通常会大于k

# %% [markdown]
# ### 使用Chain

# %% [markdown]
# #### 官方示例

# %% [markdown]
# 这部分代码执行会报错，应该是Langchain官方升级没有充分测试，已经有人提到这个问题了
#
# - https://github.com/langchain-ai/langchain/issues/17343
# - https://github.com/langchain-ai/langchain/issues/17352

# %%
from langchain.callbacks.manager import CallbackManagerForLLMRun
from langchain.llms.base import LLM
from langchain.llms import Ollama
from langchain.chains import LLMChain
from typing import Optional, List, Any
from pydantic import BaseModel, Field
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser

class LineList(BaseModel):
    lines: List[str] = Field(description="Lines of text")

class LineListOutputParser(PydanticOutputParser):
    def __init__(self) -> None:
        super().__init__(pydantic_object=LineList)

    def parse(self, text: str) -> LineList:
        print(text)
        lines = text.strip().split("\n")
        return LineList(lines=lines)

query_prompt = PromptTemplate(
    input_variables=['question', 'n_sim_query'],
    template = """你是一个AI语言模型助手。你的任务是基于给定的原始问题，再生成出来最相似的5个不同的版本。\
你的目标是通过生成用户问题不同视角的版本，帮助用户克服基于距离做相似性查找的局限性。\
使用换行符来提供这些不同的问题，使用换行符来切分不同的问题，不要包含数字序号，仅返回结果即可，不要添加任何其他描述性文本。
原始问题：{question}
"""
)
output_parser = LineListOutputParser()
llm_chain = LLMChain(llm=llm, prompt=query_prompt, output_parser=output_parser)
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(

# %%
llm_chain.invoke(qa_df.iloc[0]['question'])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.10/site-packages/langchain_core/output_parsers/pydantic.py:26, in PydanticOutputParser._parse_obj(self, obj)
#      25 if issubclass(self.pydantic_object, pydantic.BaseModel):
# ---> 26     return self.pydantic_object.model_validate(obj)
#      27 elif issubclass(self.pydantic_object, pydantic.v1.BaseModel):
#
# File /opt/anaconda3/lib/python3.10/site-packages/pydantic/main.py:568, in BaseModel.model_validate(cls, obj, strict, from_attributes, context)
#     567 __tracebackhide__ = True
# --> 568 return cls.__pydantic_validator__.validate_python(
#     569     obj, strict=strict, from_attributes=from_attributes, context=context
#     570 )
#
# ValidationError: 1 validation error for LineList
#   Input should be a valid dictionary or instance of LineList [type=model_type, input_value=1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.8/v/model_type
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 llm_chain.invoke(qa_df.iloc[0]['question'])
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain/chains/llm.py:129, in LLMChain._call(self, inputs, run_manager)
#     123 def _call(
#     124     self,
#     125     inputs: Dict[str, Any],
#     126     run_manager: Optional[CallbackManagerForChainRun] = None,
#     127 ) -> Dict[str, str]:
#     128     response = self.generate([inputs], run_manager=run_manager)
# --> 129     return self.create_outputs(response)[0]
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain/chains/llm.py:283, in LLMChain.create_outputs(self, llm_result)
#     281 def create_outputs(self, llm_result: LLMResult) -> List[Dict[str, Any]]:
#     282     """Create outputs from response."""
# --> 283     result = [
#     284         # Get the text of the top generated string.
#     285         {
#     286             self.output_key: self.output_parser.parse_result(generation),
#     287             "full_generation": generation,
#     288         }
#     289         for generation in llm_result.generations
#     290     ]
#     291     if self.return_final_only:
#     292         result = [{self.output_key: r[self.output_key]} for r in result]
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain/chains/llm.py:286, in <listcomp>(.0)
#     281 def create_outputs(self, llm_result: LLMResult) -> List[Dict[str, Any]]:
#     282     """Create outputs from response."""
#     283     result = [
#     284         # Get the text of the top generated string.
#     285         {
# --> 286             self.output_key: self.output_parser.parse_result(generation),
#     287             "full_generation": generation,
#     288         }
#     289         for generation in llm_result.generations
#     290     ]
#     291     if self.return_final_only:
#     292         result = [{self.output_key: r[self.output_key]} for r in result]
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain_core/output_parsers/pydantic.py:66, in PydanticOutputParser.parse_result(self, result, partial)
#      53 """Parse the result of an LLM call to a pydantic object.
#      54
#      55 Args:
#    (...)
#      63     The parsed pydantic object.
#      64 """
#      65 json_object = super().parse_result(result)
# ---> 66 return self._parse_obj(json_object)
#
# File /opt/anaconda3/lib/python3.10/site-packages/langchain_core/output_parsers/pydantic.py:35, in PydanticOutputParser._parse_obj(self, obj)
#      30             raise OutputParserException(
#      31                 f"Unsupported model version for PydanticOutputParser: \
#      32                     {self.pydantic_object.__class__}"
#      33             )
#      34     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 35         raise self._parser_exception(e, obj)
#      36 else:  # pydantic v1
#      37     try:
#
# OutputParserException: Failed to parse LineList from completion 1. Got: 1 validation error for LineList
#   Input should be a valid dictionary or instance of LineList [type=model_type, input_value=1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.8/v/model_type

# %% [markdown]
# #### 自定义Chain

# %%
from langchain.prompts import PromptTemplate
import re

def get_query_gen_chain(n_sim_queries):
    prompt = PromptTemplate(
        input_variables=['question', 'n_sim_queries'],
        template = """你是一个AI语言模型助手。你的任务是基于给定的原始问题，再生成出来最相似的{n_sim_queries}个不同的版本。\
    你的目标是通过生成用户问题不同视角的版本，帮助用户克服基于距离做相似性查找的局限性。\
    使用换行符来提供这些不同的问题，使用换行符来切分不同的问题，不要包含数字序号，仅返回结果即可，不要添加任何其他描述性文本。
    原始问题：{question}
    """
    )
    queries_gen_chain = (
        prompt.partial(n_sim_queries=n_sim_queries)
        | llm
        # 有时候模型不遵循指令，把前面的序号去掉
        # | (lambda x: re.sub(r'\d+\.\s', '', x.content))
        # 有时候模型不遵循指令，把前面的序号、- 去掉
        | (lambda x: [
            re.sub(r'(^\-\s+)|(^\d+\.\s)', '', item.strip()) 
            for item in x.content.split('\n') if item.strip() != ''
        ])
    )
    return queries_gen_chain

# %% [markdown]
# 测试一下

# %%
queries_gen_chain = get_query_gen_chain(3)
queries_gen_chain.invoke({'question': '报告的发布机构是什么？'})
# Out:
# ['发布该报告的是哪个组织？', '谁是负责公布这份报告的实体？', '这份报告是由哪一方正式发布的？']

# %%
def get_multi_query_retriever(k):
    retriever = MultiQueryRetriever.from_llm(
        retriever=vector_db.as_retriever(search_kwargs={'k': k}),
        llm=llm
    )
    return retriever

def get_multi_query_retriever_v2(k):
    retriever = MultiQueryRetriever(
        retriever=vector_db.as_retriever(search_kwargs={'k': k}), llm_chain=queries_gen_chain
    )
    return retriever

def get_multi_query_retriever_v3(k):
    retriever = MultiQueryRetriever(
        retriever=vector_db.as_retriever(search_kwargs={'k': k}), llm_chain=queries_gen_chain
    )
    # 检查源代码可以发现，检索时，默认是把原始问题排除出去了，增加一个包含原始查询的尝试
    retriever.include_original = True
    return retriever

# %%
multi_query_hit_stat_df = get_hit_stat_df(get_multi_query_retriever)
multi_query_hit_stat_df['multi_query'] = 'w/ multi_query'
# Out:
#   0%|          | 0/744 [00:00<?, ?it/s]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个实体或组织发布了这份报告？', '2. 谁是这份报告的出版者或赞助商？', '3. 这份报告是由哪个权威部门或机构所发布的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当这个报告是何时发布的？', '2. 该文件的发布时间是什么时候？', '3. 这份报告的公布时间具体在哪天？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测和分析2023年全球经济的增长趋势？', '2. 全球经济在2023年的增长模式有哪些独特之处，与过去相比有何异同？', '3. 对于2023年全球经济增长的特点，专家们持有什么样的观点或预判？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估当前全球贸易的增长趋势？', '2. 全球贸易的最新增长数据是怎样的？', '3. 当前有哪些因素影响着全球贸易的增长？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 未来四年全球经济发展趋势预测是什么？', '2. 预计在2024年，全球经济能否实现全面复苏？', '3. 对于2024年的世界经济状况持有什么展望和期望？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 报告中讨论了哪些当前备受关注的话题？', '2. 该报告提到了哪些引人注目的议题？', '3. 汇报中列举了多少热门话题作为焦点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 谁是撰写此研究报告的团队成员？', '2. 我如何与研究团队的负责人进行联系以获取更多信息？', '3. 是否有渠道可以获得对这份报告提出问题或评论的反馈？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What factors are driving the global economic growth in 2023?', '2. How is the global economic expansion expected to be influenced in 2023?', '3. Which sectors or economies will contribute most significantly to global growth in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪一年，发达国家的经济增长速度发生了显著变动？', '2. 2023年，发达地区经济扩张的速度有何调整或变化？', '3. 对比往常，2023年发达经济体系的增长率有什么特别之处？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估2023年全球供应链的恢复进度？', '2. 预测2023年全球供应链是否能完全恢复正常运行状态？', '3. 全球供应链在2023年的恢复态势及面临的挑战有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年的大部分时间里，美元指数的波动趋势是什么？', '2. 我想知道关于2023年全年美元指数的表现和变化情况。', '3. 能否描述一下在2023年度，美元指数的整体变动情形？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 世界经济增长呈现出哪些显著特征？', '2. 全球范围内，有哪些主要的经济恢复趋势和模式被观察到？', '3. 在全球层面上，当前的经济恢复是否显示出特定的方向或策略？']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the Eurozone's quarterly GDP growth rate for Q3 in 2023?", "2. Could you provide details on the Eurozone's GDP quarter-on-quarter expansion in the third trimester of 2023?", "3. How much did the Eurozone's GDP increase sequentially in the third quarter of 2023?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国在2023年第三季度的国内生产总值与上一季度相比增长了多少百分比？', '2. 根据最新的经济数据，2023年第三季度英国相对于前一个季度的GDP增长率是多少？', '3. 请提供一份关于2023年第三季度英国与去年同期相比GDP环比增速的数据报告。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the annualized quarter-on-quarter growth rate of US GDP in the third quarter of 2023?', '2. Could you tell me the quarterly growth rate, compounded annually for Q3 2023 in terms of US GDP?', '3. How much did US GDP grow by on a quarter-over-year basis during the third quarter of 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在2023年经济增速提升的区域有哪些？', '2. 请问2023年的哪些地区经济增长速度有望加速呢？', '3. 在2023年，哪一些地域可能迎来经济发展的提速时期？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 最近一次全球供应链压力指数达到历史最低水平是在哪一年？', '2. 请问什么时候全球供应链的压力指标创造了有史以来的最小数值？', '3. 您能提供全球供应链紧缩指数最低的具体时间吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪个月份全球工业生产达到年度最低点？', '2. 本年度内全球工业生产的低谷出现在什么时间？', '3. 全球工业产量在年内最差的时期是哪个时间段？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问全球制造业采购经理人指数（PMI）的具体数值是从哪个点下降到哪个点的？', '2. 全球制造业PMI指数经历了怎样的变化，具体是从多少降低到了多少？', '3. 您能否提供有关全球制造业PMI指数从某一值下降至另一值的信息？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个组织在2024年发布了关于全球经济增长和金融市场趋势的预测报告？', '2. 谁负责编制并发布2024年度对全球经济与金融体系的全面分析报告？', '3. 在2024年，哪个国际机构提供了全球经济前景及金融领域展望的研究报告？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. Could you provide information on the month-over-month growth rate for retail and food sales in the United States specifically for October?', '2. What is the percentage increase in sales for consumer goods and groceries in America during the month of October compared to September?', '3. How much did the total retail commerce and food industry revenues rise by in the USA when moving from September to October?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么时候全球服务业采购经理人指数（PMI）开始出现显著下降？', '2. 全球服务业的采购经理指数（PMI）自何时开始显示出明显的下滑趋势？', '3. 自哪一时刻起，全球服务业PMI指标出现了清晰的下降现象？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪个月份全球服务业采购经理人指数（PMI）达到最大值？', '2. 今年十月全球服务业的PMI数值是多少？', '3. 2022年10月全球服务业PMI的报告中显示的数据是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年的第三季度，美国的住宅建设项目有什么样的表现？', '   ', '2. 对于2023年第三季，美国在住宅领域的投资趋势是什么？', '3. 美国在2023年第三季度的住宅市场投资情况怎么样？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年第2季度，相较于2022年末，美国非金融企业的债务负担相对于其资产或收入上升了多少百分点？', '2. 从2022年底到2023年第二季度期间，美国非金融公司的负债比例相比年初时发生了怎样的变化（以百分比形式表述）？', '3. 美国的非金融企业部门在2023年第2个财政季度的负债率相较于前一年的年底水平有何变动，具体来说是增加了多少个百分点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 根据IMF的最新报告，到2023年全球的投资比率预计会是多少？', '2. 请问在IMF的预测中，2023年的全球经济投资水平会有何变化？', '3. IMF对于全球投资项目在2023年的减少程度提供了哪些数据和分析？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪些外部环境因素导致并购交易的活跃度下降？', '2. 并购市场的低迷是受何种内部和外部因素的影响？', '3. 有哪些关键因素阻碍了当前并购交易的增长势头？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个部门的债务比率在图5中有体现？', '2. 图5所展示的数据对应于哪个部门的负债水平？', '3. 在图5中，哪一部门被标记出了其特定的偿债能力比例？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 自2023年年初至八月底，全球商品贸易流量呈现出怎样的动态趋势？', '2. 在2023年的前八个季度内，全球货品贸易的强度和频率有哪些关键变化？', '3. 从一月到八月期间，全球货物交易的指数经历了哪些显著波动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What are the changes in annual percentage growth of global main economies' exports in 2023?", '2. How did the export trade volume of key global economic entities perform compared to last year in 2023?', '3. Can you provide insights on the comparative export trade growth rate between major economies worldwide for the year 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What is the World Trade Organization's forecast for the percentage growth in global merchandise trade for the year 2023?", '2. In what terms does the World Trade Organization predict the expansion of global goods trade in 2023, specifically as a point of percentage increase?', '3. Could you provide an estimate from the World Trade Organization regarding the rate at which global shipments are anticipated to grow by percentage points in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the projected levels of global trade growth for the year 2023?', '2. How much is expected to increase in international trade transactions by 2023?', '3. Can you estimate the anticipated rate of expansion for world trade in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么因素导致了欧盟国家与英国经济扩张速度的差异？', '2. 影响欧元区及英国经济增长的主要驱动力有哪些？', '3. 欧元区与英国经济表现有何关键区别，这些区别由哪些因素驱动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2024年全球经济增长率会是多少？', '2. 在哪一年，全球经济扩张的预期速度能达到2024年的水平？', '3. 按照目前的趋势，2024年全球GDP增长预测值是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估2023年第四季度美国经济的增长驱动因素及其转变？', '2. 2023年第四季度期间，影响美国经济增长的主要动力是什么，并且这些动力相较于前一时期有何改变？', '3. 在2023年的最后一个季度中，美国经济的驱动力有哪些，并分析这些驱动力相对于上个季度的动态变化情况。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪个月份，美国ISM制造业PMI指数与前一个月相比有显著变动？', '2. 美国在2023年10月份的ISM制造业PMI指数相较于上一时期发生了什么变化？', '3. 2023年10月美国ISM制造业采购经理人指数（PMI）相对于之前的月份有何调整？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在当前形势下，美国经济更可能实现温和的复苏还是陷入全面衰退？', '2. 当今背景下，是美国经济有希望平稳过渡还是不可避免地走向萧条？', '3. 如今的情形下，美国经济维持稳定增长的可能性大还是面临深度下滑的风险更大？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前小企业对市场前景的看法如何？', '2. 小型企业主对未来经济环境的信心水平是多少？', '3. 目前，小企业的经营乐观度处于什么状态？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在8月至10月期间，消费者的信心指数是否超过了其长期的平均值？', '2. 对比过去数年，今年8-10月的消费者信心水平是高于、低于还是接近于平均水平？', '3. 从8月到10月，消费者的信心指数与历史长期内的基准相比有何变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['Version 1: What was the employment index reading for the Eurozone in October?', 'Version 2: Could you provide the number for the Employment component of the PMI report for October in the Eurozone?', "Version 3: How high did the Employment Index climb during the month of October specifically within the Eurozone's Performance Monitoring (PM) system?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国预算责任部门预测，何时才能看到普通民众的生活水平开始回升？', '2. 依据英国财政责任机构的报告，何时我们可以预期民众的生活质量得到改善和恢复？', '3. 根据官方经济分析，英国民众在哪个时间点能预见到生活成本下降并重新提升生活质量？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 欧洲央行为什么不再继续提高利率，是否标志着其加息进程的终结？', '2. 当前情况下，为何欧洲央行被普遍认为已接近或完成其加息周期？', '3. 是什么因素促使市场预期欧洲央行将停止进一步增加基准利率？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the economic sentiment indicator for the Eurozone in October 2023?', '2. Could you provide the index value of the general economic climate in the Eurozone for the month of October in the year 2023?', '3. How high was the composite leading indicator for economic conditions in the European Union region during the period of October 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the projected economic growth rate for the Eurozone in 2023?', "2. How fast is the Eurozone's economy anticipated to grow in the year 2023?", '3. Could you estimate the expected economic expansion of the Eurozone in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 沙特阿拉伯在2023年第2季度的GDP增长速度为多少？', '2. 在2023年的第二季度，沙特的GDP相比前一年同期增长了多少百分比？', '3. 请问在2023年第二季度期间，沙特的GDP同比增长率能达到多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the percentage increase in South Africa's CPI compared to the same period last year for September 2023?", '2. How much did the Consumer Price Index (CPI) rise by on a yearly basis in South Africa for the month of September in 2023?', '3. Can you provide the inflation rate, measured by the Consumer Price Index (CPI), for September 2023 compared to the figure from September 2022 in South Africa?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2024年全球快速增长的经济体将实现怎样的整体经济增长率？', '2. 我们如何预测在2024年新兴国家和地区的总体经济发展速度？', '3. 根据当前趋势，2024年新兴市场经济增长预期是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前环境下，有哪些国家应优先推动可再生能源的发展？', '2. 哪些国家在当今形势下特别适合并应当增加对可再生能源的投资和利用？', '3. 鉴于现有条件，哪些国家最需加快向可再生能源转型的步伐？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问在2023年举办的金砖国家峰会中，中国政府公布了哪些专项基金计划？', '2. 2023年金砖会议期间，中国政府提出了哪些专门的资金方案或项目？', '3. 在2023年的金砖会议上，中国宣布了哪些具体的专项资金用于支持合作与发展？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2024年美国经济的增长速度会达到多少？', '2. 对于2024年的美国国内生产总值，经济学家们有什么增长预期？', '3. 根据当前的趋势和分析，在哪一年，全球预测机构估计美国的GDP增长率将会达到最大？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计中国在2024年的国内生产总值增长率为多少？', '2. 在2024年，中国经济扩张的速度会达到何种水平？', '3. 根据目前的经济趋势，中国2024年度的GDP增长预期值是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测2023年英国的国内生产总值增长百分比？', '2. 预计在2023年，英国经济的增长速度会达到多少？', '3. 对于2023年的英国GDP预测增长率值是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the specific date when the European Central Bank announced its decision to halt interest rate hikes?', '2. When did the European Central Bank officially declare that it would cease increasing interest rates?', '3. Can you provide information on the exact moment the European Central Bank made public its plan to stop raising interest rates?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问在日本时间2022年10月31日时，日本中央银行的基準利率保持在哪个水平？', '2. 在2022年10月31日，日本央行的基准利率被定在了什么位置？', '3. 日本的中央银行在2022年10月31日决定将基准利率维持在多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问在2023年内，英格兰银行进行了多少次加息？', '2. 英格兰银行于2023年度执行了几次加息政策调整？', '3. 在二零二三年中，英国中央银行的加息次数是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the change in basis points made by the Federal Reserve on February 1st?', '2. How many basis points did the Federal Reserve adjust on February 1st?', '3. Could you tell me how much the Federal Reserve altered in terms of basis points on February 1st?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['版本一：欧洲中央银行于2023年3月16日设定的利息率是多少百分比？', '版本二：在2023年3月16日，欧洲央行确定的利率水平为何？以百分比形式表示。', '版本三：2023年3月16日，欧洲央行实施的基准利率是多高的百分比值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国央行在6月22日的货币政策调整中，基点变化幅度是多少？', '2. 自从6月22日以来，英格兰银行的基准利率发生了多少个基点的波动？', '3. 请问在6月22日的市场活动中，英格兰银行的利率调整了多少个基点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the English abbreviations for financial risk indicators in the US economic crisis?', '2. Can you provide me with the acronyms used for indicators of potential financial risks associated with the US financial crisis?', '3. Which English shorthand terms are utilized for measuring financial risks during a US economic downturn?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年，是否有提到欧元区M3、M2和M1的年度增长比例？', '2. 关于2023年的数据，是否详细说明了欧元区M3、M2以及M1的同比增长率？', '3. 针对2023年的情况，能否提供关于欧元区M3、M2和M1增速的相关信息？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何计算2023年瑞士法郎相对于美元的价值增长？', '2. 2023年瑞士法郎对美元汇率上升了多少百分比？', '3. 在2023年，瑞士法郎与美元之间的价值变化有多大？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估和预测美元汇率的变化趋势？', '2. 近期及未来，影响美元波动的主要因素有哪些？', '3. 什么指标可以帮助我们理解美元价值的动态演变过程？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 美联储的预期在市场中受到怎样的关注？', '2. 市场参与者如何预测和评估美联储的行动？', '3. 对于美联储的决策，当前市场普遍抱有何种期望或预期？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估当前欧元与英镑之间的兑换率？', '2. 汇率变动下，欧元与英镑间的换算关系有何趋势？', '3. 实时查询欧元和英镑之间汇率的变动情况。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the distinctive features of global economic growth in 2023?', '2. How does the worldwide economic expansion manifest its uniqueness in 2023?', '3. Can you highlight any notable characteristics of global economic development for the year 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何衡量全球贸易的当前增长趋势？', '2. 全球范围内，贸易活动的扩张速度有多快？', '3. 近期全球贸易量的增长态势是怎样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预测在二零二四年时，全球经济发展趋势将会是怎样的？', '2. 对于二零二四年的全球经济增长前景持有什么样的期望或预测？', '3. 在二零二四年，我们有理由期待经济会有哪些复苏的迹象或者变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 报告中讨论了哪些当前受到广泛关注的议题？', '2. 有哪些热门话题在研究报告里有所涉及？', '3. 请列举出报告中提到的一些当前社会热议的问题。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 谁是这份研究报告的作者或研究团队？', '2. 我如何与完成这份研究报告的专业团队取得联系？', '3. 这份报告是由哪个机构或组织发布的，可以联系到他们吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估与预测2023年全球经济增长的动力及其变动趋势？', '2. 影响2023年全球经济发展的关键增长力量和其预计的变化是什么？', '3. 预测2023年全球经济增长的驱动力，并分析这些驱动因素可能如何变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 2023年全球发达国家的经济增长率会有什么波动？', '2. 预测2023年发达经济体系中的增长速度会有哪些变化和趋势？', '3. 在2023年度，预期发展中国家的经济扩张率会发生什么样的调整？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在今年，全球供应链是否已经显示出复苏迹象？', '2. 截至2023年底，全球供应链的稳定性和效率有了哪些改善？', '3. 全球供应链在2023年的恢复进展和挑战有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测2023年的美元指数总体趋势？', '2. 在2023年内，美元指数的预期变动情况分析是什么？', '3. 专家对于2023年整体美元指数走向的预估和解读。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 有哪些特征表明全球经济正在经历复苏？', '2. 全球经济的复苏有什么显著的特点和趋势吗？', '3. 在当前背景下，全球经济增长模式与过去相比有何不同之处？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the quarterly GDP growth rate for Europe in the third quarter of 2023?', "2. How much did the eurozone's GDP increase by on a sequential basis during Q3 2023?", '3. Could you provide details on the year-over-year and quarter-over-quarter GDP expansion in Europe as of the end of Q3, 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国在2023年第三季度的国内生产总值（GDP）与上一季度相比增长了多少百分比？', '2. 我想知道的是，2023年第三季末英国的季度GDP增长率。', '3. 请问在2023年的第三季度，英国的经济环比增速达到了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. How fast was US GDP growing in Q3 2023 on an annualized basis?', '2. What is the quarterly growth rate of US GDP for the third quarter of 2023, expressed as an annual percentage?', '3. In what percentage terms does the US GDP expand year-over-year during the third quarter of 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在哪几个区域，其经济增长速度会在2023年显著提升？', '2. 请问有哪一些地域被预测将在2023年度加速推进经济发展？', '3. 您能指出哪些地区在二零二三年内预计会迎来经济增速的加速吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么时候全球供应链的压力指标达到了历史上的最轻程度？', '2. 全球供应链系统在何时显示出其历史上最小的紧张状态？', '3. 历史上，全球供应链压力指数何时首次触及最低水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在年内哪个时间点全球工业生产达到了最低水平？', '2. 今年内全球工业生产的最低产出发生在什么时间段？', '3. 全球工业产量在本年度的低谷出现在哪一时期？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What specific values did the global manufacturing PMI index transition from and to?', "2. Can you provide details on the start and end points of the global manufacturing Purchasing Managers' Index (PMI)?", "3. Which initial and final figures were observed for the global manufacturing sector's performance as indicated by the PMI metric?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个组织在2024年发布了全球经济发展与金融形势的预测报告？', '2. 在2024年，谁负责发表了关于全球经济和金融市场状况的年度展望报告？', '3. 请问有哪个国际机构于2024年公布了其对全球经济及金融领域的未来预测分析报告？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the month-to-month growth rate in US retail and food sales for October?', '2. How much did US retail and food sales increase on a sequential basis in October?', '3. Can you provide the percentage rise in US retail and food commerce for the month of October?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问全球服务行业采购经理人指数（PMI）何时出现了明显的下降趋势？', '2. 自何年起，全球服务业的采购经理人指数显示出了显著下滑现象？', '3. 全球服务业采购经理人指数从哪个时间点开始出现下滑并显著减少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. In which quantity did the Global Services PMI Index stand in October?', '2. What was the measurement of the Global Service Sector PMI for October?', '3. Could you tell me how much the Global Service Industry PMI registered in October?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 美国在2023年第3季度的住宅建设活动表现怎么样？', '2. 请问在2023年第三季度，美国房地产市场中的住宅投资趋势是怎样的？', '3. 2023年的第三季，美国住宅经济的投资情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在二零二三年第二季度相较于二零二十二年底，美国非金融企业的债务比率发生了多大的百分比变动？', '2. 美国非金融企业在从二零二二年底到二零二三年二季度的时间段里，其负债水平变化了多少个百分点？', '3. 请问与二零二二年底相比，二零二三年第二季度时美国非金融企业部门的杠杆率有何百分比上的改变？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 根据IMF的预测，2023年的全球投资预计会下降到哪个水平？', '2. IMF对于2023年全球的投资状况有何预估？他们会预测投资率为多少？', '3. 请问在IMF的报告中，他们预测在2023年度时全球的投资率将会下滑至何种程度呢？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么因素导致并购市场持续低迷？', '2. 并购活动不振的原因有哪些？', '3. 影响并购交易活跃度的因素包括哪些方面？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个部门在图5中显示了高负债水平？', '2. 图5中的数据用于评估哪个部门的财务负担状况？', '3. 在图5上，哪个单位的负债比率是主要的关注点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何描述2023年前八个月全球货物贸易量的波动趋势？', '2. 全球货物贸易量在2023年的头八个月中的表现有哪些变化和动态？', '3. 从数值的角度看，2023年1月至8月期间全球货物贸易量指数有何起伏？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在全球经济中，与上一年相比，主要国家和地区的2023年出口额增长率如何？', '2. 对比过去几年，2023年的全球顶级经济体的出口贸易增长速度呈现出怎样的趋势？', '3. 2023年时，全球最大的几个经济体在出口贸易方面相对于前一年的增长率是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计世界贸易组织在2023年将全球商品贸易的增长率设定为多少个百分点？', '2. 在2023年的经济展望中，世界贸易组织给出了全球货物贸易增长的预期百分比是多少？', '3. 世界贸易组织预测2023年度全球商品出口会增加百分之几？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2023年的全球贸易活动将会有怎样的增幅？', '2. 对于2023年度的国际交易增长，有哪些建设性的预测和分析？', '3. 专业人士如何看待2023年国际贸易的增长趋势及其可能的具体数值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么关键因素推动或限制了欧洲联盟与英国的经济扩张速度？', '2. 欧元区和英国的经济增长受哪些主要因素驱动或制约？', '3. 影响欧元区及英国经济增长的主要动力是什么？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预测的2024年全球经济增长率是多少？', '2. 到2024年，全球经济发展的预测增长率为多少？', '3. 对于2024年度的世界经济，预计的增长速度为何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. How are the driving forces for economic growth in the United States expected to shift in Q4 2023?', '2. What factors are anticipated to influence and alter the momentum of US economic expansion in the final quarter of 2023?', "3. Can you outline potential changes or developments in the key drivers powering America's GDP growth in the fourth quarter of 2023?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the change in the US ISM Manufacturing PMI index from September to October 2023?', "2. How did the ISM Manufacturing Purchasing Managers' Index for the USA evolve between September and October of 2023?", '3. Can you compare the US Manufacturing PMI score for October 2023 with its value in September, specifically regarding any shifts or variations?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前形势下，美国经济更可能实现平稳复苏还是滑入衰退？', '2. 在当前环境中，美国的经济是倾向于温和增长还是陷入经济衰退的可能性更大？', '3. 根据目前的情况分析，美国经济有更大的可能性避免深度衰退，还是会经历经济增长的放缓？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前小企业发展状况下的企业主信心水平如何？', '2. 小企业在当前环境中的经营自信度表现怎样？', '3. 现今经济形势下，小型企业的领袖对未来的预期和信心情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在8月至10月期间，消费者信心指数相对于长期平均值的变动情况是什么？', '2. 对比历史数据，8至10月份的消费者信心指数相较于其长期内的均值有何变化？', '3. 长期平均水平下，8-10月份消费者信心指数的表现如何进行评估？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['- 在2022年10月，欧洲地区的采购经理人指数（PMI）中的就业情况如何？', '- 欧元区于2022年10月份在经济活动和就业方面表现出了怎样的采购经理人指数（PMI）值？', '- 请问，当月欧元区的PMI数据是否包含了有关就业的具体指标，并且能否提供2022年10月的相关数值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国预算责任办公室预测的英格兰人民生活水平改善何时出现？', '2. 当依据英国预算责任办公室的观点，英国百姓的生活质量将实现反弹的时间点是什么时候？', '3. 根据英国预算责任局的说法，英格兰民众能否在什么时候看到生活标准的提升？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 欧洲中央银行的利率上调过程为何被普遍认为接近尾声？', '2. 怎么理解现在的情况意味着欧洲央行提高利率的道路基本上终结了？', '3. 是否存在充分的理由表明，欧洲央行已经宣布其加息行动即将全面停止？']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What is the Eurozone's economic sentiment indicator for October 2023?", "2. Can you provide the points value of the eurozone's business climate index in October 2023?", "3. How much did the European Commission forecast for the eurozone's confidence index to be in October 2023?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问您能预测一下在2023年，整个欧洲地区的经济发展速度吗？', '2. 在2023年的预期中，欧洲经济的增长率会达到一个什么样的水平呢？', '3. 您能不能预估一下，在二零二三年时，欧元区的经济增长趋势和速率？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the annual growth rate in GDP for Saudi Arabia during the second quarter of 2023?', "2. How much did Saudi Arabia's GDP increase by annually in the second quarter of 2023 compared to the previous year?", '3. Can you tell me the percentage increase in GDP for Saudi Arabia from Q2 2022 to Q2 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the percentage increase in South Africa's CPI compared to September 2022 as of September 2023?", '2. Can you provide the inflation rate for September 2023 in South Africa when compared to the same period in 2022?', '3. How much did the Consumer Price Index (CPI) increase by in South Africa from September 2022 to September 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计到2024年，全球新兴市场国家的总经济增长率会达到多少？', '2. 在2024年的预测中，新兴市场经济体的整体增长速度预估是多少？', '3. 据预测，在2024年度时新兴经济体将实现怎样的整体经济增速？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪些国家在目前的环境需求下应该优先推动可再生能源的发展？', '2. 面对当前全球变暖的趋势，有哪些国家急需增加其可再生能源应用以减缓影响？', '3. 依据现有资源和环境挑战，哪些国家应当将重点放在发展可再生能源上？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 2023年金砖国家峰会中，中国政府承诺设立的专项基金具体有哪些？', '2. 在2023金砖国家会议期间，中国官方提到了哪些针对特定领域的专项财务支持计划？', '3. 请问在2023年举办的金砖会议上，有关于中国的专项资金政策公告是哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2024年美国经济增长率会达到多少？', '2. 对于2024年的美国经济，分析师们估计的GDP增长预期是多少？', '3. 基于当前趋势和因素分析，2024年度美国GDP的增长预测值是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预测在2024年中国经济增长的幅度会达到多少？', '2. 估计中国在二零二四年时的国内生产总值会有怎样的增长速度？', '3. 对于2024年中国国内生产总值（GDP）的增长预期是多高？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 今年预计英国经济的增长速度会达到多少？', '2. 对于2023年，经济学家预测英国的GDP将增长多少百分比？', '3. 在即将到来的一年内，英国GDP的预期增长幅度是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 欧洲中央银行是在哪个时间点决定暂不提高利率的？', '2. 请问欧洲央行何时宣布了他们将停止加息的计划？', '3. 当前，欧洲央行的具体声明是什么时候作出的，即他们打算暂时不再上调利率？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the base interest rate decided by the Japanese Central Bank on October 31st, and did it remain unchanged?', '2. How much did the benchmark interest rate of the Japanese Banking System stay constant at after the decision made on October 31st?', '3. Could you tell me if the Japanese Monetary Authority kept its standard interest rate stable on October 31st, and what was that rate?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英格兰银行在二零二三年的货币政策调整中，有多少次提高了利率？', '2. 在2023年，英格兰银行的基准利率上调了几次？', '3. 英国中央银行于2023年度的升息行动共进行了多少回？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['Version 1: What was the change in basis points for the Federal Reserve on February 1st?', 'Version 2: How many basis point adjustments did the Federal Reserve make on February 1st?', 'Version 3: Could you tell me the magnitude of the base-point movement by the Federal Reserve on February 1st?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the interest rate set by the European Central Bank on March 16th in percentage form?', '2. Could you provide details about the percentage interest rate decided upon by the ECB on the 16th of March?', '3. Please furnish information regarding the interest rate, expressed as a percentage, determined by the European Central Bank on March 16th.']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the change in basis points for the Bank of England's interest rate on June 22nd?", '2. By how many basis points did the Bank of England alter its interest rate on June 22nd?', '3. Could you provide information on the adjustment made by the Bank of England to its interest rates on June 22, specifically in terms of basis points?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the English abbreviations for financial crisis risk indicators in the US?', '2. Which acronyms represent key risk factors for financial crises in America?', '3. Can you list the shortened forms of indicators used to assess financial risks during a crisis in the United States?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年度中，欧元区域内的M3、M2以及M1指标的年度增长速度有哪些详细数据？', '2. 有关于2023年欧元区的货币供应量层次（包括M3、M2和M1）的同比变化情况的信息吗？', '3. 能否提供一份关于2023年时，欧元区域内M3、M2和M1三个不同层面货币存量的年度增长比例报告？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the appreciation rate of Swiss Francs against US dollars in 2023?', '2. By what percentage did the value of Swiss Francs increase relative to US dollars in the year 2023?', '3. How much has the purchasing power of US dollars declined compared to Swiss Francs in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估美元近期的波动趋势？', '2. 美元汇率的变化模式是什么样的？', '3. 有哪些因素影响了美元的价值走向？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 美联储政策变动对当前市场有何影响？', '2. 投资者如何预测并适应美联储的决策？', '3. 根据目前的经济指标，市场的共识看法是美联储会采取何种行动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估欧元与英镑之间的货币兑换率？', '2. 汇率波动情况下，当前欧元对英镑的市场交换比率是多少？', '3. 请解释一下现在的欧元/英镑汇率是如何确定的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年1月1日至2023年11月15日的时间段内，哪个行业实现了最大的增长幅度？', '2. 请问，在2023年1月至2023年11月期间，哪个产业的涨幅最高？', '3. 哪个领域在2023年的前11个月中表现最为突出，取得了最高的增长率？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪个时间点图20显示了价格变动范围？', '2. 图20中的波动幅度时间段是何时？', '3. 请问图20所示的价格浮动区间是在什么时段？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年的美国国债发行量与前一年相比，发生了怎样的变动？', '2. 从2022年到2023年，美国政府在国债方面的发行规模有何调整？', '3. 比较2023年和2022年期间，美国国债的市场供给有何不同？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 房贷在美国居民总负债中的占比情况如何？', '2. 美国家庭债务组成中，房贷部分的比例是多少？', '3. 分析一下在美国居民债务中，房贷占据多大的份额？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估美联储加息政策对于美国房地产市场潜在风险等级的变化？', '2. 美联储提高利率后，美国房地产市场的风险评级会受到怎样的影响？', '3. 加息环境下，美联储政策对美国房产市场风险评价有何具体变动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 居住房贷的主要类型是什么，并且它们的市场份额如何分布？', '2. 哪种类型的居民房贷占据了当前市场中的主要份额？', '3. 在居民房贷领域，目前哪些贷款种类是占比最高的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 按照John Burns研究和咨询公司的报告，有多少计划中的房主因预测的房贷利率超过5.5%而决定放弃购房？', '2. John Burns的研究指出，在考虑的房贷利率高于5.5%时，有多少比例的潜在购房者选择不购买房产？', '3. 基于John Burns公司的调查结果，对于那些打算买房的人群，当预计利率上升至5.5%以上时，其购房意愿的比例是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 未来在2024年，美国联邦储备系统可能会采取哪些政策行动？', '2. 对于2024年的经济展望，预计美国联邦储备委员会会有何决策和调整？', '3. 在2024年的时间框架下，美国联邦储备银行可能对利率水平、货币供应量或其他关键宏观经济指标有什么规划或变动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年第二季度，全美范围内的个人住宅抵押贷款违约比例是多少？', '2. 截至2023年第二季度末，美国的单户家庭房贷逾期比率具体数值是多少？', '3. 请问在2023年的4月至6月期间，美国个人住房按揭贷款拖欠率达到了哪个水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2021年第四季度，与去年同期相比，美国的商业地产价值上涨了多少百分比？', '2. 请问，在疫情后的2021年第四季度，美国的商业房产市场较去年同季增长了多少？', '3. 美国在2021年最后一个季度的商业房地产价格相比于前一年同一时期，增加了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 银行业在2023年第二季度的商业房地产贷款逾期比例为多少？', '2. 在2023年的中期，银行对商业地产的贷款违约率如何？', '3. 请问，在2023年第2季度时，银行业商业房产贷款的延迟还款比率是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What percentage of commercial real estate loans does it account for in the assets of medium and small banks?', '2. How significant is the contribution of commercial property financing to the asset portfolio of regional banking institutions?', '3. Can you estimate the proportion of commercial property loans within the total assets of community and mid-sized banking systems?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 谁是报告的出版者或发起方？', '2. 制作这份报告的是哪个组织或实体？', '3. 该报告是由哪个部门或者官方机构发布的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问报告是在哪一天发布的？', '2. 报告的发布时间点是何时？', '3. 您能告诉我报告的公布日期吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the notable characteristics of global economic growth in 2023?', '2. Can you describe the distinctive features and trends of worldwide economic expansion for the year 2023?', '3. Which aspects define the state of global economic development as observed in 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估全球贸易的增长趋势？', '2. 近年来，全球贸易量的变化情况如何？', '3. 全球贸易增长的主要驱动力是什么？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预测二零二四年全球经济发展趋势和恢复的可能性有多大？', '2. 到二零二四年时，全球经济从现有困境中复苏的前景如何评估？', '3. 对于二零二四年全球经济增长和经济复原力的预期是什么样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 报告中讨论了哪些当前最受关注的议题？', '2. 在该报告里，有哪些话题是具有热度和广泛讨论的？', '3. 请问这份报告提到了哪几项引人注目的焦点问题？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 谁是撰写这份报告的研究团队成员？', '2. 如何与制作此报告的学术群体建立联系？', '3. 提供关于制作该报告的研究组的联络信息，如电子邮件或社交媒体链接。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测2023年全球经济增长的趋势和驱动力？', '2. 鉴于当前经济环境，2023年的全球经济增长有哪些潜在的推动因素和障碍？', '3. 2023年影响全球经济发展的主要动力有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 2023年发达经济体的经济增长率有何变动？', '2. 发达国家在二零二三年的经济成长情况是怎样的？', '3. 预计二零二三年发达地区经济增速会有哪些调整和趋势？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 全球供应链在2023年的状况和改善趋势是什么？', '2. 对于2023年，全球供应链的全面恢复程度和主要挑战有哪些？', '3. 我们能否预测2023年全球供应链的整体稳定性和弹性？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the overall trend of the US Dollar Index in 2023?', '2. How has the performance of the US Dollar Index been throughout 2023?', '3. Can you describe the trajectory of the USD Index for the year 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the distinctive features of global economic recovery?', '2. Could you describe the characteristics and trends in global economic resurgence?', '3. How does worldwide economic revival manifest itself, and what significant patterns can be observed?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年的第三季度中，欧洲经济联盟的国内生产总值（GDP）较上一季度增长了多少？', '2. 欧元区在2023年第3季度的GDP相对于第2季度的增长率是多少百分比？', '3. 请问在2023年第三个财政季度里，欧元区域的GDP环比增长速度是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国在2023年第三季度的GDP环比增长率具体为多少？', '2. 按照环比计算，2023年第三季时英国的GDP增长了多少百分比？', '3. 我们如何获取2023年7月至9月期间英国国内生产总值（GDP）环比增速的数据？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 我们能查询到2023年第三季度美国GDP环比增长率的具体数值吗？', '2. 在2023年的第三季度，美国的GDP按季度折算的增长速度是多少？', '3. 求解2023年三月份至十二月份期间，美国经济活动环比增长的比例。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在哪几个区域，其经济增长速度会在2023年度显著提升？', '2. 到2023年时，有哪些地理区域的经济发展预测将加速增长？', '3. 在全球范围内，哪些地区被预测在2023年内会有更快的经济增速？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 最近一次全球供应链压力指数达到历史低点发生在什么具体时间？', '2. 何时能观察到全球供应链压力指数创下了自记载以来的最低水平？', '3. 能否指明全球供应链压力指数出现历史性新低的具体日期？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在哪个月份全球工业生产的产出达到了本年度的最低点？', '2. 今年内，全球工业产量在什么时候跌至全年最低水平？', '3. 全球工业生产在什么时间点录得本年度的最小产值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What specific values did the Global Manufacturing PMI Index drop from?', "2. Can you provide details on the starting and ending values of the Global Manufacturing Purchasing Managers' Index (PMI)?", '3. Which two numerical points does the Global Manufacturing Production Management Indicator (PMI) encompass in its recent fluctuation?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个组织在2024年发布了全球的经济与金融市场预测报告？', '2. 谁负责编制并将在2024年发布全球经济和金融形势展望的年度报告？', '3. 在2024年，由哪个机构或实体制定了关于全球宏观经济及金融市场的未来分析报告？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['- 请问美国在10月份的零售与食品销售环比增长率为多少？', '- 想了解的是，10月份美国的零售及食品销售额环比增速具体是多少？', '- 在这个查询中，我想知道的是，美国10月的零售和食品销售相比上个月的增长率是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 何时全球服务业采购经理人指数(PMI)开始出现显著下降？', '2. 全球服务业PMI指标在哪个时间点显示出明显的下滑趋势？', '3. 自何年何月起，全球服务业PMI数据出现了明显的下降？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['- 在哪个月份，全球服务业采购经理人指数（PMI）达到峰值？', '- 今年10月的全球服务业PMI数据是多少？', '- 全球服务业PMI指数在2023年10月份的具体数值是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年的第三季度，美国的住宅建设项目发展状况是怎样的？', '2. 美国在2023年第三季的住房市场投资表现如何？', '3. 2023年期间，美国住宅投资领域有何显著特征和趋势？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年第二季度和2022年末之间，美国非金融企业部门的债务比率经历了怎样的变化？', '2. 美国非金融企业在从2022年底过渡到2023年二季度时，其负债状况有何百分比上的变动？', '3. 与年底2022年的数据相比，在2023年第二季度中美国非金融企业的平均负债率发生了多少个百分点的调整？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 根据IMF的预测，2023年的全球投资增长率预计是多少？', '2. IMF对2023年全球投资情况的最新评估显示了怎样的比率？', '3. 请问IMF在近期报告中提到，2023年全球投资率会降低到哪个水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么关键因素导致了并购市场的持续萎靡？', '2. 并购活动低迷的原因有哪些方面被指出了？', '3. 影响当前并购交易活跃度的主要因素有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪个部门的负债比率在图5中被描绘？', '2. 图5中的数据对应于哪个部门的财务负担比例？', '3. 在图5所示的数据分析中，哪个组织或部门的借贷额度占比最高？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 自2023年1月至8月，全球货物贸易的流通程度有何动态变化？', '2. 在2023年的前八个月里，全球商品交易总额经历了怎样的增长或下降趋势？', '3. 从2023年初到8月底，全球商品贸易指数呈现出什么样的波动和演变？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 与去年同期相比，2023年全球主要经济体的出口贸易增长率有何波动？', '2. 在2023年，主要国家和地区的出口贸易在国际市场上较之于2022年的增长速度如何变化？', '3. 全球最主要的经济体，在2023年的出口贸易相对于前一年度的增长率呈现出何种趋势？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 根据世界贸易组织，2023年的全球商品贸易增长率预计为多少百分比？', '2. 世界贸易组织预估在2023年全球货物贸易的增长幅度将会达到多少个百分点？', '3. 在2023年，根据世界贸易组织的预测，全球货物贸易增长的预期速率是多少个百点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the projected levels of international trade growth for the year 2023?', '2. Could you estimate the expected rate of increase in global trade transactions by 2023?', '3. How might international trade volume be anticipated to expand or contract by the end of 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 什么关键要素推动或阻碍了欧元区与英国的经济成长？', '2. 欧元区和英国经济增长的主要驱动及抑制因素是什么？', '3. 影响欧元区和英国经济增长的关键因素有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在2024年度全球经济增长率是多少？', '2. 到2024年，全球经济扩张的预测值是多少？', '3. 2024年的全球经济产出增长预期是什么水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What factors are driving the economic growth in the United States for the fourth quarter of 2023?', '2. How is the momentum of economic expansion shifting in America as we approach the last quarter of 2023?', "3. Can you analyze the changes in growth drivers contributing to the US economy's performance during the final period of 2023?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. How did the ISM manufacturing PMI index in the United States change from September to October 2023?', '2. Could you compare the industrial production indicator released by the ISM for the US in October 2023 compared to its previous month?', "3. What alterations occurred to the ISM's Manufacturing Business Conditions Index when comparing October 2023 with its preceding period?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在当前局势下，您认为美国经济实现温和增长的可能性与陷入衰退相比，哪一种更有可能发生？', '2. 当我们评估目前的经济状况时，美国经济能否避免深度衰退并实现平稳下降的趋势被看作是较可能发生的情况吗？', '3. 根据现在的信息和预测，在不考虑极端情况的前提下，美国经济能够实现软着陆而不是遭受衰退的可能性是否更高？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前小企业发展中的自信心水平如何？', '2. 小企业在当前经济环境下对未来发展抱有信心吗？', '3. 对于小型企业来说，目前他们对未来市场的乐观程度是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 消费者信心指数在8月至10月间相对于其长期平均值有什么变化？', '2. 在8至10月份期间，消费者信心指数与历史平均水平之间的比较显示出了什么趋势？', '3. 比较8-10月的消费者信心指数与长时间跨度内的平均水平有何不同？']
# INFO:langchain.retrievers.multi_query:Generated queries: 
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计2024年的全球经济增长率是多少？', '2. 对于2024年，全球的经济扩张速度预测值是怎样的？', '3. 在2024年中，经济学家对全球经济活动的增长速度有何预期？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the dynamics driving US economic growth in Q4 2023?', "2. How is consumer spending influencing the US economy's growth trajectory for the last quarter of 2023?", '3. What factors will impact US economic expansion in the fourth quarter of 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['- 如何比较2023年10月的美国ISM制造业PMI指数与前一个月的数据？', '- 2023年10月美国ISM制造业采购经理人指数（PMI）较上个月出现了什么变动？', '- 在哪一年的背景下，美国在2023年10月份的ISM制造业PMI指标相对于之前一个月发生了变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在当前环境下，美国经济实现温和复苏的概率比陷入衰退更大吗？', '2. 给定目前的形势，美国经济避免深度衰退并实现软着陆的可能性有多大？', '3. 鉴于现在的条件，是美国经济会实现平稳降速还是更有可能进入衰退状态？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 当前，小型企业在经济中的信心水平处于什么状态？', '2. 小型企业对当前经济环境抱持怎样的信心度？', '3. 目前，小企业的经营和扩张计划受哪些因素影响，显示出何种程度的信心？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在8月至10月期间，消费者信心指数相对于其长期平均值有何表现？', '2. 消费者在8月至10月间的信心水平是高于、低于还是接近历史长期平均值？', '3. 分析自8月至10月，消费者信心指数与通常的长期平均水平之间的差距。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['Version 1: What was the employment index reading for the Eurozone in October?', 'Version 2: Can you provide the employment component of the PMI index for October in the Eurozone region?', "Version 3: How high did the employment sector perform in the Purchasing Managers' Index (PMI) report for the Eurozone during the month of October?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 英国预算责任局预测何时能改善普通民众的生活成本状况？', '2. 依据英国预算责任办公室的评估，何时能看到公众生活水平的提升与反弹？', '3. 当前根据英国预算责任局的数据分析，英国民众的生活质量何时会开始得到恢复和增长？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 欧洲中央银行的加息进程为何被认为已接近尾声？', '2. 为什么当前观点认为欧洲央行不会再有进一步的加息行动？', '3. 分析并阐述导致市场预测欧洲央行加息周期即将停止的原因。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the economic sentiment indicator for the Eurozone in October 2023?', "2. Could you provide the score of the Eurozone's business climate index for the month of October in the year 2023?", '3. How high was the composite indicator for economic confidence in the Eurozone during October 2023?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问专家们对于2023年欧元区经济增长预测是多少？', '2. 欧元区内多个经济学家对2023年GDP增长率的预期平均值是多少？', '3. 预计至2023年，欧洲经济联盟的年度增长速度会达到多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the year-on-year growth rate of Saudi Arabia's GDP in Q2 of 2023?", "2. Can you provide details on how much Saudi Arabia's GDP increased by in the second quarter of 2023 compared to the previous year?", '3. How has the GDP of Saudi Arabia expanded or contracted during the second quarter of 2023 when compared to the same period in the preceding year?']
# INFO:langchain.retrievers.multi_query:Generated queries: ["1. What was the percentage increase in South Africa's CPI compared to September 2022 as of September 2023?", '2. How much did the Consumer Price Index (CPI) rise by in South Africa from September 2022 to September 2023?', "3. Can you provide the inflation rate for September 2023, specifically focusing on the year-over-year change in South Africa's CPI?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计到2024年，全球发展中国家的经济增长率将达到多少？', '2. 在2024年的预测中，新兴市场的整体经济扩张速度是多少？', '3. 根据预测，2024年新兴国家的总体经济发展指数增长预期为多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪些国家在现有情况下应优先发展可再生能源技术？', '2. 鉴于当前环境需求，有哪些国家需加强利用可再生能源的策略？', '3. 如何根据当下形势识别出应该大力发展可再生能源的国家？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问在2023年举办的金砖国家峰会上，中国提出了哪些专项基金？', '2. 2023年度的金砖会议中，中国政府公布了哪些专门的资金援助项目？', '3. 在2023金砖会议上，中国宣布了哪些用于特定领域的专项资金支持？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在2024年，美国经济的增长速度将会达到多少？', '2. 对于2024年的经济增长情况，是否有权威机构对美国进行了一定的预测值？', '3. 到2024年时，国际金融市场预计会对美国GDP增长率会有何评估？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the forecasted GDP growth rate for China in the year 2024?', "2. In which percentage will China's GDP be expected to grow in 2024 according to predictions?", '3. Could you provide an estimate of the GDP increase in China for the fiscal year 2024?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 预计在2023年，英国经济将实现多大的增长速度？', '2. 对于2023年英国的经济增长情况有什么预测？', '3. 想了解2023年英格兰地区国家生产总值（GDP）的增长预期，请问有相关的预测吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 欧洲中央银行是在哪一年的哪个时间点宣布将停止升息的？', '2. 请问欧洲央行于何年何月何日宣布了不再增加利率？', '3. 当欧洲央行决定暂停提升基准利率时，具体是在什么时候做出这一声明的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the fixed interest rate set by the Bank of Japan on October 31st, and how was it determined?', '2. Can you provide details about the benchmark interest rate decided by the Japanese central bank as of October 31st?', "3. How did the Bank of Japan's decision on October 31st affect its key interest rate, and what factors influenced this determination?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 今年英国央行的加息次数达到了多少？', '2. 在2023年里，英格兰银行进行了几次加息？', '3. 英国中央银行于二零二三年执行了多轮加息政策？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What was the change in basis points for the Federal Reserve on February 1st?', '2. How many basis points did the Federal Reserve adjust on February 1st?', '3. Could you tell me how much the interest rate changed by basis points for the Fed on February 1st?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['Version 1: What was the interest rate percentage set by the European Central Bank on March 16th?', "Version 2: Can you provide the interest rate in percent for Europe's central bank as of March 16th?", 'Version 3: How high was the interest rate, measured in percentages, determined by the European Central Bank on March 16?']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 请问英格兰银行于6月22日调整了多少个基点的利率？', '2. 英格兰银行在6月22日的政策变更中，其基准利率变化了多少点？ ', '3. 在6月22日的市场活动中，英格兰银行的利率变动了多少个基点？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What are the English abbreviations for risk indicators of the US financial crisis?', '2. Could you provide me with the acronyms used for assessing risks related to the U.S. financial crisis in English?', "3. I'm looking for the English shorthand terms that represent key indicators of risk during the American financial crisis. Can you help?"]
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年中，是否有详细的数据记录了欧元区M3、M2以及M1的年度增长率变化？', '2. 对于2023年的经济数据，是否提供了欧元区M3、M2和M1的同比增速情况分析？', '3. 2023年度内，欧元区的金融统计中对于M3、M2和M1的货币供应量增速是如何进行描述的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年，瑞郎相对于美元的汇率增长了多少百分比？', '2. 我想知道在2023年里，1瑞士法郎能兑换多少美金？', '3. 请问2023年的瑞士法郎对美元的价值上涨了多大程度？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测美元未来的汇率变动趋势？', '2. 自从上一次评估以来，美元价值有何改变和预期将会怎样发展？', '3. 全球金融市场上对美元走强或走弱有什么见解和分析？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 美联储政策决定在当前市场环境下的预测如何？', '2. 投资者如何根据对美联储行动的期望来调整他们的策略？', '3. 基于对美联储未来决策的预期，市场情绪和反应模式会是怎样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何预测欧元与英镑之间的汇率变动？', '2. 当前情况下，欧元兑换英镑的汇率趋势如何？', '3. 汇率市场上，欧元对英镑的价值走向是怎样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 自《巴黎协定》实施以来，中国与海洋伙伴在新能源方面的合作项目有哪些突破或进展？', '2. 请问在《巴黎协定》生效后，中国和海上国家在新能源领域有哪些合作案例或合作方向？', '3. 请列举几个《巴黎协定》生效之后，在新能源领域中中国与海事相关国家的合作实例。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 美联储提高利率对美国房地产市场的具体影响是什么？', '2. 如何理解美联储加息与美国房地产价格变动之间的关系？', '3. 加息政策实施后，美国的居住房地产市场会经历哪些可能的变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 截至当前，美国住宅房地产市场的总价值是多少？', '2. 美国住宅房地产业的总资产规模现在为多少？', '3. 美国目前的住宅房地产市场整体估值如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 房贷在美国居民总负债中的占比情况如何？', '2. 美国家庭债务组成中，房贷占据多大份额？', '3. 如何评估美国居民债务构成时，房贷的比重是关键因素吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 如何评估美联储加息对美国房地产市场风险的总体影响？', '2. 美联储加息后，美国房地产市场的不同风险领域受到了怎样的冲击？', '3. 美国房地产市场在面对美联储加息时的风险变化情况分析。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 哪种类型的房屋贷款在居住市场中的份额最高？', '2. 居住房贷里，哪个种类的贷款占据了主流地位？', '3. 在住宅金融领域，哪种贷款产品占比最突出？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 据John Burns研究与咨询公司发布的最新调查结果，在考虑购买房屋时，有多少意向买家明确表示如果贷款利息超过5.5%，他们将放弃购房计划？', '2. John Burns的调研显示，基于房贷利率超过了5.5%这一条件，计划购房者中有多少比例的人决定不再考虑购房？ ', '3. 依据John Burns研究与咨询公司提供的数据分析，在其调查中，有多少未来购房者表态若贷款成本超出5.5%，他们将停止购房意愿？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 2024年中，美联储的政策调整有哪些可能性？', '2. 美联储在2024年的货币政策会采取什么行动？', '3. 预测2024年美联储将如何应对经济状况及市场波动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年第二季度，美国的平均个人住宅按揭贷款违约比率是多少？', '2. 2023年4月至6月间，全美范围内的个人住房抵押贷款的未支付比例是多少？', '3. 美国个人家庭在2023年第二季度拖欠房贷的比例情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2021年第四季度，与疫情前相比，美国商业房地产的价格增长了多少百分比？', '2. 美国的商业房地产市场在经历了疫情冲击后，于2021年末的季度同比增长率具体是多少？', '3. 从2020年底到2021年底的这段时间内，美国商业房地产价格的季度变化幅度是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 在2023年第二季度中，银行业内对于商业地产贷款的违约比例如何？', '2. 银行业在2023年的上半年，特别是第二季度，商业地产贷款中的逾期还款比率是多少？', '3. 请问，在2023年第二季度，银行业的商业房地产信贷债务未能按时支付的比例情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 按照比例，商业房产贷款在中小金融机构的总资产中占据多大份额？', '2. 中小型银行里，用于商业地产的投资贷款通常占其总资产的百分比是多少？', '3. 在中小银行的资产管理框架内，商业房地产贷款的大致占比情况是怎样的？']

# %% [markdown]
# 从日志中可以看出，使用`MultiQueryRetriever.from_llm`构造的相似问，可以看出，都带有数字前缀，而且有些是英文问题，这主要是由于内置的Prompt是英文的

# %%
multi_query_v2_hit_stat_df = get_hit_stat_df(get_multi_query_retriever_v2)
multi_query_v2_hit_stat_df['multi_query'] = 'w/ multi_query_llm_chain'
# Out:
#   0%|          | 0/744 [00:00<?, ?it/s]
# INFO:langchain.retrievers.multi_query:Generated queries: ['报告是由哪个组织发布的？', '谁能确定这份报告的来源和编制单位？', '请问是哪个部门或团体发布了此报告？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['何
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年10月的欧洲经济信心指数数值是多少？', '在2023年10月份，欧元区的经济预期指数达到了多少水平？', '查询一下，2023年10月份欧元区域的经济展望指标是什么值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预计在2023年度，欧洲地区的经济增长率会是多少？', '2023年时，人们预测的欧元区域经济将会有怎样的增长速度？', '根据当前趋势，到2023年，欧元区内国家的经济发展速度预期如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年第二季度沙特经济的增长速度是多少？', '2023年四月至六月期间，沙特的GDP增长了多少百分比？', '从今年一月至三月到四月至六月，沙特的经济增长情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年9月南非消费价格指数相较于去年同期增长了几个百分点？', '在2023年9月，与上一年同一时期相比，南非的通货膨胀率提高了多少百分比？', '南非在2023年9月份的CPI同比上升了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预测2024年新兴市场国家的总体经济增长率会是多少？', '2024年的新兴经济体整体经济发展速度估计如何？', '新兴经济体在2024年的综合经济增长率预估为多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['当前环境下，哪些国家应着重推动可再生能源的发展？', '在现今情况下，有哪些国家急需提升其可再生能源的利用与开发水平？', '鉴于目前状况，哪些国家需要增加对可再生能源的投资和研究？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年金砖国家会议期间，中国政府推出了哪些专项基金？', '在2023的金砖峰会上，中国具体提出了哪几项资金援助计划？', '为了在2023年的金砖会议上加强合作，中国宣布了什么形式的资金支持？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2024年的美国经济预计会有怎样的增长速度？', '2024年美国国内生产总值的增长率预估是多少？', '未来几年，美国的经济增长趋势如何？特别关注2024年的情况。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['中国在2024年的经济增长预期如何？', '预计2024年中国国内生产总值的增长率会达到多少？', '2024年中国经济增长的预测值是什么？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预测2023年英国经济的增长率如何？', '2023年度英国GDP增长预期值是多少？', '2023年，英国的经济增长预测情况怎样？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧洲中央银行何时决定中止提高利率？', '欧洲央行何时发表了关于停止加息的声明？', '当欧洲央行宣布不再加息时，具体是什么时候？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['日本中央银行于10月31日保持基本利息水平为多少？', '10月31日，日本金融监管机构宣布的基本利率是多少？', '请问，在2021年10月31日，日本央行的基准利率是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['英国央行于2023年内总共上调了几次利率？', '2023年期间，英国央行的利率调整次数是多少？', '请问，2023年中，英国银行进行了多少次加息？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['基点变化情况是什么时候发生的？', '美联储2月1日的操作中涉及到多少基点调整？', '在二月一日，美联储对基准利率做了怎样的基点改动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧洲央行于3月16日设定的利率水平为多少？', '在3月16日，欧洲央行宣布的基准利率是多少？', '请问2023年3月16日时，欧洲中央银行调整后的利息率是哪个百分比？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['英格兰银行6月22日的利率调整了几个基点？', '6月22日，英格兰银行的利率变动了多少个基点？', '请问英格兰银行在6月22日的时候利率有变化吗？如果有，请告诉我变化了多少基点。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美国金融危机风险指数的英文简称是什么？', '在英语中，代表美国经济危机预警信号的是哪个术语？', '查找美国金融市场危机预警指标的英文标识符？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年，关于欧元区域的M3，M2及M1的年度增长趋势有报道吗？', '在2023年，对欧元区M3、M2和M1的增长百分比有何更新信息？', '2023年的新闻中有提到欧元区M3、M2和M1的同比变化情况吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['瑞士法郎在2023年相对于美元的增值程度如何？', '2023年的瑞士法郎与美元之间的汇率增长了多少？', '到2023年，瑞士法郎对美元的升值比例达到了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美元的价值变动趋势是什么？', '如何评估美元的波动情况？', '近期及未来的美元汇率变动有哪些预测？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联
素有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预测2023年时，国际货币基金组织对波湾地区的六个国家有怎样的经济增长预期？', '2023年国际货币基金组织对于海湾合作委员会的六个成员国的经济成长速度有何估计？', '根据国际货币基金组织的报告，2023年海湾六国的平均经济扩张率预计会是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['海湾地区六个国家的经济发展中面临的关键挑战有哪些？', '六个海湾国家在经济发展的过程中遇到的主要障碍是什么？', '海湾国家六强经济体的主要困境和局限性体现在哪里？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['海湾国家为何要推动经济结构调整？', '海湾地区六国的经济发展为何需改变方向？', '什么促使海湾六国寻求经济模式转变？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['沙特全面绿色计划的具体实施内容有哪些？', '你能详细说明一下沙特全面绿色行动中的各个项目吗？', '列举并解释沙特阿拉伯全面绿色战略中包含的所有举措。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['请问在2022年度，外国直接投资流入阿联酋的情况如何？', '求解2022年时，阿联酋吸引的外资直接投资额数据。', '阿联酋于2022年的外商直接投资总额是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['阿联酋在2022年的对外直接投资增长了多少？', '2022年度，阿联酋的对外直接投资增长率如何？', '请问2022年阿联酋的对外直接投资增长速率是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['全球石油消费中中国扮演什么角色？', '在世界石油消耗方面，中国处于怎样的水平？', '中国在全球石油市场中占有多大的消费份额？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['探讨《巴黎协定》实施后，在新能源领域中，中国与海洋相关合作的具体情况如何？', '评估《巴黎协定》签署后，中国和海洋地区在新能源开发方面的协作进展是怎样的？', '在《巴黎协定》框架下，中国与沿海国家的新能源合作项目有哪些显著变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储调整利率对美国房地产市场有何具体影响？', '在美联储加息的情况下，美国的住宅房地产市场会受到怎样的冲击？', '如何评估美联储加息策略对美国房地产业的潜在效应？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['当前美国的住宅房地产市场总值是多少？', '美国房地产市场中的住宅部分价值如何计算？', '求解现今美国住宅房地产市场的总体估值。']
# INFO:langchain.retrievers.multi_query:Generated queries: ['在美国家庭的债务组成里，房贷通常占据多大的份额？', '如何评估美国普通家庭中房贷在总负债中的比重？', '探讨一下，在美国居民的经济负担中，房贷占比的情况是怎样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储提高利率如何改变美国房产市场的潜在风险？', '在当前利率调整背景下，美国房地产领域面临的不确定性有哪些变化？', '若美联储加息，对于美国房地产市场而言，风险等级会如何评估和变动？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['居住房贷的主要类型有哪些？其中哪一种占比最高？', '在各类住房贷款中，哪个种类的贷款拥有最大的市场份额？', '请问用于居住目的的贷款中，最普遍或使用频率最高的贷款类型是什么？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['约翰伯恩斯调研报告指出，有多少潜在购房人因为贷款利率超过5.5%，决定放弃购买房产？', '根据John Burns研究和分析，有多少计划中的买家表示若房贷利率高于5.5%会停止购房？', 'John Burns的调查发现，对于哪些比例的购房者来说，当房贷利息达到或超越5.5%时，他们将不再考虑购房？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2024年时，美国联邦储备系统（Fed）有可能会采取哪些行动？', '预测在2024年中，美联储可能会有哪些政策调整或变动？', '到2024年为止，根据当前的经济趋势，美联储会考虑进行哪些策略变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美国2023年第二季度的个人住房贷款违约比率是多少？', '2023年4月至6月期间，美国平均的未偿还按揭贷款情况如何？', '在美国，2023年春季末的家庭房贷拖欠比例达到了何水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美国2021年末商业地产市场变化了多少？', '2021年第四季度，美国商业房地产价值较前一年同期有何变动？', '新冠疫情后，到2021年底，美国商房价格同比增长了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年第二季度，银行业的商业地产贷款逾期比例如何？', '2023年4月至6月期间，银行业对商业房产的贷款违约率是多少？', '在2023年的春季和夏季，银行业内针对商业房地产的信贷延迟支付情况有何数据？']
# INFO:langchain.retrievers.multi_query:Generated queries: 
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['自《巴黎协定》签署以来，中国和海上合作伙伴在可再生能源项目上展开了哪些合作？', '在《巴黎协定》实施之后，中国与海洋伙伴在清洁能源领域的合作取得了哪些进展？', '《巴黎协定》生效后，中国与海洋国家在新能源领域有哪些具体的合作案例？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储调高利率后，美国的房地产市场会发生什么变化？', '当美联储增加利息时，对美国的住宅房市有何潜在影响？', '若联邦储备提升贷款成本，美国的居住房产市场会受到何种影响？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['当前美国的住宅房地产市场估值是多少？', '美国房地产住宅部分的市场总价值如何计算？', '想知道现在美国的房产住宅市场总额是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['在美国住房贷款是否构成居民总负债的主要部分？', '房贷在普通美国家庭的财务负担中占据多大份额？', '美国居民的总债务组成里，房贷占比情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储提高利率如何改变美国房地产市场的潜在风险等级？', '在当前的金融环境下，调整联邦基金利率对美国房产市场风险评估有何具体影响？', '若美联储决定加息，这将怎样重塑美国房地产行业的风险评分？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['居民房贷市场中，哪类贷款占据主要份额？', '在个人住房贷款领域，哪一种类型最为普遍？', '从居民角度出发，哪种房贷产品占比最高？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['John Burns研究和咨询的研究中提到，在考虑购房的人群中，有多少人因预期贷款利率超过5.5%，而决定放弃购买？', '根据John Burns研究与咨询公司的调查报告，有多少计划中的购房者表示如果房贷利率高于5.5%，他们将不再考虑买房？', '在John Burns的评估结果中，具体有多少比例的购房者在得知潜在的房贷利率可能超出5.5%后，选择不进行购房决策？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2024年时，美国联邦储备系统有可能采取哪些行动？', '2024年里，我们可以预期美联储会进行怎样的政策调整？', '探讨一下，在2024年度中，美联储可能会实施的经济策略有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美国在2023年第二季度的个人住房贷款违约比率是多少？', '2023年4月至6月期间，全美个人房产抵押贷款逾期比例为多少？', '到2023年夏季，平均家庭按揭贷款拖欠情况如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美国商业房地产市场在2021年底的表现如何？', '2021年第四季度与去年同期相比，美国商业房地产价格增长了多少百分比？', '疫情过后，2021年末美国的商业地产投资情况有何变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['银行在2023年第二季度的商业房产贷款违约比率如何？', '2023年4月至6月期间，银行业对商业房地产贷款的逾期偿还比例是多少？', '想知道2023年二季银行业商业用房信贷的坏账情况吗？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['商业房地产贷款在中小规模金融机构的总资产中所占比例约为多少？', '中小银行总资产里，商业房产贷款大概占据多大份额？', '评估一下，在小型及中型银行的整体资产配置中，用于商业房地产业务的贷款占比情况如何？']

# %%
hit_stat_df = pd.concat([orig_query_hit_stat_df, multi_query_hit_stat_df, multi_query_v2_hit_stat_df, multi_query_v3_hit_stat_df])

# %%
hit_stat_df.groupby(['multi_query', 'top_k'])['hit'].mean().reset_index().rename(columns={'hit': 'hit_rate'})
# Out:
#                             multi_query  top_k  hit_rate
# 0                        w/ multi_query      1  0.344086
# 1                        w/ multi_query      2  0.537634
# 2                        w/ multi_query      3  0.591398
# 3                        w/ multi_query      4  0.677419
# 4                        w/ multi_query      5  0.720430
# 5                        w/ multi_query      6  0.752688
# 6                        w/ multi_query      7  0.731183
# 7                        w/ multi_query      8  0.741935
# 8              w/ multi_query_llm_chain      1  0.397849
# 9              w/ multi_query_llm_chain      2  0.569892
# 10             w/ multi_query_llm_chain      3  0.634409
# 11             w/ multi_query_llm_chain      4  0.709677
# 12             w/ multi_query_llm_chain      5  0.720430
# 13             w/ multi_query_llm_chain      6  0.741935
# 14             w/ multi_query_llm_chain      7  0.806452
# 15             w/ multi_query_llm_chain      8  0.806452
# 16  w/ multi_query_llm_chain_orig_query      1  0.387097
# 17  w/ multi_query_llm_chain_orig_query      2  0.548387
# 18  w/ multi_query_llm_chain_orig_query      3  0.612903
# 19  w/ multi_query_llm_chain_orig_query      4  0.688172
# 20  w/ multi_query_llm_chain_orig_query      5  0.774194
# 21  w/ multi_query_llm_chain_orig_query      6  0.741935
# 22  w/ multi_query_llm_chain_orig_query      7  0.774194
# 23  w/ multi_query_llm_chain_orig_query      8  0.784946
# 24                                  w/o      1  0.462366
# 25                                  w/o      2  0.591398
# 26                                  w/o      3  0.688172
# 27                                  w/o      4  0.774194
# 28                                  w/o      5  0.806452
# 29                                  w/o      6  0.817204
# 30                                  w/o      7  0.838710
# 31                                  w/o      8  0.849462

# %%
import seaborn as sns

sns.barplot(x='top_k', y='hit', hue='multi_query', data=hit_stat_df, errorbar=None)
# Out:
# <Axes: xlabel='top_k', ylabel='hit'>

# %% [markdown]
# # 预测

# %%
from langchain.llms import Ollama

ollama_llm = Ollama(
    model='qwen2:7b-instruct',
    base_url='http://localhost:11434'
)

# %%
ollama_llm.invoke('你是谁')
# Out:
# '我是阿里云研发的一款超大规模语言模型，我叫通义千问。作为一个AI助手，我的目标是帮助用户获得准确、有用的信息，解决他们的问题和困惑。无论是学术知识、技术问题、日常建议还是娱乐话题，我都尽力提供高质量的回答。如果你有任何问题需要解答或有任务需要完成，请随时向我提问！'

# %%
def rag(question, n_chunks=3):
    prompt_tmpl = """
你是一个金融分析师，擅长根据所获取的信息片段，对问题进行分析和推理。
你的任务是根据所获取的信息片段（<<<<context>>><<<</context>>>之间的内容）回答问题。
回答保持简洁，不必重复问题，不要添加描述性解释和与答案无关的任何内容。
已知信息：
<<<<context>>>
{{knowledge}}
<<<</context>>>

问题：{{question}}
请回答：
""".strip()

    retriever = get_multi_query_retriever_v2(n_chunks)
    chunks = retriever.invoke(question)[:n_chunks]
    assert len(chunks) == n_chunks
    
    prompt = prompt_tmpl.replace('{{knowledge}}', '\n\n'.join([doc.page_content for doc in chunks])).replace('{{question}}', question)

    return ollama_llm(prompt), chunks

# %%
print(rag('2023年10月美国ISM制造业PMI指数较上月有何变化？')[0])
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年10月的美国ISM制造业PMI是否比9月有变动？', '2023年10月与前一个月相比，美国ISM制造业PMI有什么不同？', '从2023年9月到10月，美国ISM制造业PMI指数有何变化？']
# /opt/anaconda3/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# 2023年10月美国ISM制造业PMI指数较上个月大幅下降了2.3个百分点。

# %%
prediction_df = qa_df[qa_df['dataset'] == 'test'][['uuid', 'question', 'qa_type', 'answer']].rename(columns={'answer': 'ref_answer'})

def predict(prediction_df, n_chunks):
    prediction_df = prediction_df.copy()
    answer_dict = {}

    for idx, row in tqdm(prediction_df.iterrows(), total=len(prediction_df)):
        uuid = row['uuid']
        question = row['question']
        answer, chunks = rag(question, n_chunks=n_chunks)
        assert len(chunks) <= n_chunks
        answer_dict[question] = {
            'uuid': uuid,
            'ref_answer': row['ref_answer'],
            'gen_answer': answer,
            'chunks': chunks
        }
    prediction_df.loc[:, 'gen_answer'] = prediction_df['question'].apply(lambda q: answer_dict[q]['gen_answer'])
    prediction_df.loc[:, 'chunks'] = prediction_df['question'].apply(lambda q: answer_dict[q]['chunks'])

    return prediction_df

# %%
n_chunks = 3

pred_df = predict(prediction_df, n_chunks=n_chunks)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['在8月至10月期间，消费者的信心水平是高于还是低于通常的长线平均值？', '对比其长期平均水平，8至10月份的消费者信心指数处于什么状态？', '从长远角度来看，8-10月的消费者信心度是否超过或落后于典型水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧盟地区10月就业PMI数据具体数值是多少？', '在10月份，欧盟的PMI就业指标达到了多少水平？', '想知道的是，10月时欧元区的PMI就业指数值为多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['英国预算责任机构预测的民众生活水平回升时间点是什么时候？', '按照英国预算责任部门的说法，何时能预期民众的生活质量得到改善和提升？', '依据英国预算与支出评估办公室的意见，英国民众的生计恢复到正常水平需要多久？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧洲央行宣布停止加息的主要原因是什么？', '有哪些迹象表明欧洲央行的加息周期已接近尾声？', '影响欧洲央行决定停止加息的因素有哪些？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年10月份的欧元区经济信心指数值为多少？', '在2023年10月，预计欧元区的经济景气指数会达到怎样的水平？', '查询2023年10月期间，欧元区整体经济景气度指数的具体数值？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年时，欧洲的经济增长速度会有怎样的预测？', '到2023年，人们预期欧元区的经济发展会达到什么程度？', '对于2023年，专业经济学家对欧元区经济增长率有什么看法？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年第二季度沙特阿拉伯的经济增速是多少？', '在2023年的前半年中，沙特的GDP增长了多少百分比？', '沙特在2023年4月至6月期间的GDP同比增长率具体数值为多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['2023年9月南非的消费者价格指数相比去年上涨了百分之几？', '在2023年的9月份，南非的通货膨胀率达到了多少？', '请告诉我，在2023年9月，南非的消费物价较上一年同期增长了多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预期在2024年新兴市场国家的经济增长率会有多少？', '到2024年时，预测的新兴经济区的总经济扩张速度是多少?', '请问专家们对2024年新兴国家的集体经济发展速度有何预估？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['探索哪些国家在现有环境下需着重推动可再生能源的发展？', '在现今的形势下，有哪些地区特别需要关注和提升可再生能源技术的应用？', '如何识别并支持那些在当前条件下迫切需要扩大可再生能源使用的国家？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['金砖会议中，中国在2023年发布了哪些专项基金？', '2023年期间，中国的具体专项资金在金砖国家会议上有何公布？', '请问，在2023年的金砖国家合作框架内，中国政府提出了哪些专项基金？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['预测2024年美国经济总值增长速度会有多少？', '预计到2024年时，美国的国内生产总值会以多快的速度增加？', '在2024年看来，美国的经济增长预期是怎样的？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['中国在2024年的经济增长率预计会达到多少？', '2024年中国国内生产总值的预测增长率为多少？', '对于2024年，专业人士对中国GDP的增长速度有怎样的预估？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['今年英国经济的增长预估如何？', '预计2023年的英国民经济增速会有怎样的表现？', '对2023年度英国GDP增长预测值有多少了解？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧洲央行的加息暂停决定是什么时候公布的？', '何时欧洲央行公开了它将停止加息的消息？', '欧洲央行宣布不再提高利率的具体时间点是？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['日本中央银行在10月31日宣布的基准利率是多少？', '10月31日，日本金融管理机构保持关键利率不变，具体数值为何？', '在2022年10月31日，日本央行是上调、下调还是维持其基础利率水平？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['英国中央银行于2023年进行了几次加息？', '2023年里，英格兰银行的加息次数是多少？', '想知道2023年内英国央行为何调整了利率？一共加了多少次息？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储于2月1日调整了基准利率吗？', '2月1日时，联邦储备系统有进行基点变动吗？', '从2月1日起，联邦基金利率发生了怎样的变化？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧洲央行于2023年3月16日宣布的基准利率为何？', '2023年3月16日，欧洲中央银行的利率调整到了多少？', '查询显示，欧洲央行在2023年3月16日的利率水平是多少？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['英
']
# INFO:langchain.retrievers.multi_query:Generated queries: ['欧盟在判定某些补贴为可申诉补贴后，可能采取的行动是什么？', '当欧盟确认某个补贴为可申诉的类型后，它将怎样应对这种情况？', '如果欧盟裁定某补贴为可争议性补贴，它通常会实施什么样的策略或步骤？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['全球发展中三国如何在关键的国际论坛上表现出积极的参与？', '2023年度的重要国际聚会上，发展中国家展现出了怎样的活力和影响力？', '在哪些主要的国际会议中，未来几年内可能会看到更多来自发展中国家的活跃表现？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['美联储在2024年的货币政策计划是什么？', '预计2024年美联储会采取何种货币政策行动？', '2024年度美联储的利率政策走势预测如何？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['全球资金状态及货币市场基金在二零二四年的发展趋势怎么样？', '预测二零二四年全球经济环境下货币市场基金的表现与资金流动情况会是怎样的？', '到二零二四年，全球金融市场中的资金配置与货币市场基金会呈现何种走向？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['海湾国家在面临经济增速下降及全球性经济难题时，实施了哪些策略？', '针对经济扩张减缓与全球性的经济压力，海湾地区采取了何种应对措施？', '当遭遇经济增长放缓和全球范围内的经济问题时，海湾国家启动了哪些行动方案？']
# INFO:langchain.retrievers.multi_query:Generated queries: ['新增的房贷中，浮动利率的贷款比例发生了怎样的变动？背后的原因是什么？', '在新发放的房贷里，采用浮动利率的比例有无波动？能否解释一下导致这种趋势转变的因素？', '浮动利率房贷在最新批出的贷款中所占份额有何变化动态？其背后的驱动因素是什么？']

# %% [markdown]
# # 评估

# %%
from langchain_openai import ChatOpenAI
import time

judge_llm = ChatOpenAI(
    api_key=os.environ['LLM_API_KEY'],
    base_url=os.environ['LLM_BASE_URL'],
    model_name='qwen2-72b-instruct',
    temperature=0
)

def evaluate(prediction_df):
    """
    对预测结果进行打分
    :param prediction_df: 预测结果，需要包含问题，参考答案，生成的答案，列名分别为question, ref_answer, gen_answer
    :return 打分模型原始返回结果
    """
    prompt_tmpl = """
你是一个经济学博士，现在我有一系列问题，有一个助手已经对这些问题进行了回答，你需要参照参考答案，评价这个助手的回答是否正确，仅回复“是”或“否”即可，不要带其他描述性内容或无关信息。
问题：
<question>
{{question}}Í
</question>

参考答案：
<ref_answer>
{{ref_answer}}
</ref_answer>

助手回答：
<gen_answer>
{{gen_answer}}
</gen_answer>
请评价：
    """
    results = []

    for _, row in tqdm(prediction_df.iterrows(), total=len(prediction_df)):
        question = row['question']
        ref_answer = row['ref_answer']
        gen_answer = row['gen_answer']

        prompt = prompt_tmpl.replace('{{question}}', question).replace('{{ref_answer}}', str(ref_answer)).replace('{{gen_answer}}', gen_answer).strip()
        result = judge_llm.invoke(prompt).content
        results.append(result)

        time.sleep(1)
    return results

# %%
pred_df['raw_score'] = evaluate(pred_df)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
pred_df['raw_score'].unique()
# Out:
# array(['是', '否'], dtype=object)

# %%
pred_df.loc[:, 'score'] = pred_df['raw_score'].replace({'是': 1, '否': 0})
_ = pred_df.pop('raw_score')
# Out:
# /tmp/ipykernel_3815971/1969662583.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pred_df.loc[:, 'score'] = pred_df['raw_score'].replace({'是': 1, '否': 0})

# %%
pred_df['score'].mean()
# Out:
# 0.71

# %%
pred_df.to_excel(os.path.join(expr_dir, 'prediction.xlsx'), index=False)
